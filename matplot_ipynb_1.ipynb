# %% [markdown]
# <a href="https://colab.research.google.com/github/Mounika2004/python/blob/main/matplot_ipynb_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Matplotlib pyplot
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 9])
ypoints = np.array([0, 260])

plt.plot(xpoints, ypoints)
plt.show()

# %%
## Matplotlib Markers
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2,6,8])
ypoints = np.array([3,8,1,10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([6, 56, 8, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %%
## Bar graphs
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["M", "O", "U", "N","I"])
y = np.array([3, 8, 1, 10,6])

plt.bar(x,y)
plt.show()

# %%
## Pie Charts
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
## Bar Graph
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Math", "Vdc", "Clang", "Chem","Python"])
y = np.array([3, 8, 7, 10,6])

plt.bar(x,y)
plt.show()

# %%
## Pie Chart with marks based
import matplotlib.pyplot as plt
import numpy as np

y = np.array([91, 78, 89, 77,88,69,90,54])
a = (["vdc", "chem", "maths1", "clad", "worhop", "maths2", "Cprgrm", "eng"])

plt.pie(y,labels=a)
plt.show()

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.2.2

# %%
## Plotting
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3, 6])
ypoints = np.array([6, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
## Ploting with X points
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([6, 8, 4, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %%
## Dottted line (style)
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([6, 3, 9, 13])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
## Dashed Line
plt.plot(ypoints, linestyle = 'dashed')

# %%
## Shorted Syntaax
plt.plot(ypoints, ls = ':')

# %%
## Create labels for plot
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([78, 89, 90, 97, 100, 178, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
## Matplotlib Markers
import numpy as np
import matplotlib.pyplot as plt

x = np.array([67, 78, 56, 95, 180, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([10, 8, 7, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
## Mark each point with star
...
plt.plot(ypoints, marker = '*')
...

# %%
## Line colour
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5, 9, 3, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %%
# green 
...
plt.plot(ypoints, c = '#4CAF50')
...
# Out:
# Ellipsis

# %%
## Pink
...
plt.plot(ypoints, c = 'hotpink')
...

# %%
## Wide Line
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 6, 10])

plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %%
## Multiple lines
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
## Specifiyiing  X and Y point values for both lines
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 6, 10])
y2 = np.array([6, 9, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
## Title and Labels
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([6, 8, 9, 10])
y2 = np.array([6, 8, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([90, 85, 190, 95, 100, 109, 110, 185, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
## position to the Title
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %%
## Add grid lines to the plot
import numpy as np
import matplotlib.pyplot as plt

x = np.array([79, 85, 98, 95, 100, 150, 110, 115, 120, 125])
y = np.array([440, 250, 270, 470, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()
